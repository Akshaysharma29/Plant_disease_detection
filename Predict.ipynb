# %%
import cv2
import numpy as np
from keras.models import load_model
from keras.preprocessing import image
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
model = load_model('Disease_detector.h5')

# %%
path = '/home/akshay/Documents/7th Semester/Minor project/crowdai_test/test/0a0f6fd5968c16c209cf0776b0a66bb3.jpg'

# %%
img = cv2.imread(path)
img = np.array(img)
img = img/255.0
plt.imshow(img)

# %%
img = image.load_img(path, target_size=(28,28))
img = image.img_to_array(img)
img = img/255.0
img = np.array(img)
plt.imshow(img)

# %%
 img = img.reshape((1,28,28,3))

# %%
print(img.shape)
# Out:
# (1, 28, 28, 3)

# %%
ans = model.predict(img).argmax()

# %%
print(ans)
# Out:
# 24
